# %% [markdown]
# # Data Cleaning Before Loading

# %% [markdown]
# This notebook is for exploring the dataset before loading to the database for better organizing the data.

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
products = pd.read_csv('../data/raw/products.csv')
transactions = pd.read_csv('../data/raw/transactions.csv')
users = pd.read_csv('../data/raw/users.csv')

# %% [markdown]
# ## Explore users

# %%
users
# Out:
#                              ID               CREATED_DATE  \
# 0      5ef3b4f17053ab141787697d  2020-06-24 20:17:54.000 Z
# 1      5ff220d383fcfc12622b96bc  2021-01-03 19:53:55.000 Z
# 2      6477950aa55bb77a0e27ee10  2023-05-31 18:42:18.000 Z
# 3      658a306e99b40f103b63ccf8  2023-12-26 01:46:22.000 Z
# 4      653cf5d6a225ea102b7ecdc2  2023-10-28 11:51:50.000 Z
# ...                         ...                        ...
# 99995  61fc06d41febf771966da8fa  2022-02-03 16:46:12.000 Z
# 99996  6391e7ef90ad5449ec5f782d  2022-12-08 13:34:39.000 Z
# 99997  637d5efdd6f2a49c49934dcb  2022-11-22 23:45:05.000 Z
# 99998  5f0de23b05d8a6147dc0cafa  2020-07-14 16:50:04.000 Z
# 99999  5e7ab436905e9512ff44abc8  2020-03-25 01:30:30.000 Z
#
#                       BIRTH_DATE STATE LANGUAGE  GENDER
# 0      2000-08-11 00:00:00.000 Z    CA   es-419  female
# 1      2001-09-24 04:00:00.000 Z    PA       en  female
# 2      1994-10-28 00:00:00.000 Z    FL   es-419  female
# 3                            NaN    NC       en     NaN
# 4      1972-03-19 00:00:00.000 Z    PA       en  female
# ...                          ...   ...      ...     ...
# 99995  1992-03-16 08:00:00.000 Z    CA       en  female
# 99996  1993-09-23 05:00:00.000 Z    MO       en  female
# 99997  1983-04-19 00:00:00.000 Z    RI       en  female
# 99998  1995-06-09 04:00:00.000 Z    DE       en  female
# 99999  1995-12-15 05:00:00.000 Z    VA      NaN  female
#
# [100000 rows x 6 columns]

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            100000 non-null  object
#  1   CREATED_DATE  100000 non-null  object
#  2   BIRTH_DATE    96325 non-null   object
#  3   STATE         95188 non-null   object
#  4   LANGUAGE      69492 non-null   object
#  5   GENDER        94108 non-null   object
# dtypes: object(6)
# memory usage: 4.6+ MB

# %%
# Remove " Z" from end of date
users['CREATED_DATE'] = users['CREATED_DATE'].str.replace(' Z', '')
users['BIRTH_DATE'] = users['BIRTH_DATE'].str.replace(' Z', '')

# Convert to datetime
users['CREATED_DATE'] = pd.to_datetime(users['CREATED_DATE'])
users['BIRTH_DATE'] = pd.to_datetime(users['BIRTH_DATE'])

users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            100000 non-null  object
#  1   CREATED_DATE  100000 non-null  datetime64[ns]
#  2   BIRTH_DATE    96325 non-null   datetime64[ns]
#  3   STATE         95188 non-null   object
#  4   LANGUAGE      69492 non-null   object
#  5   GENDER        94108 non-null   object
# dtypes: datetime64[ns](2), object(4)
# memory usage: 4.6+ MB

# %%
# Change "NaN" or "nan" to np.nan
users = users.replace('NaN', np.nan)
users = users.replace('nan', np.nan)

# Check for missing values
users.isnull().sum()
# Out:
# ID                  0
# CREATED_DATE        0
# BIRTH_DATE       3675
# STATE            4812
# LANGUAGE        30508
# GENDER           5892
# dtype: int64

# %%
# Check for duplicates
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check duplicated id in users
users['ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check null values in id
users['ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            100000 non-null  object
#  1   CREATED_DATE  100000 non-null  datetime64[ns]
#  2   BIRTH_DATE    96325 non-null   datetime64[ns]
#  3   STATE         95188 non-null   object
#  4   LANGUAGE      69492 non-null   object
#  5   GENDER        94108 non-null   object
# dtypes: datetime64[ns](2), object(4)
# memory usage: 4.6+ MB

# %%
users.head()
# Out:
#                          ID        CREATED_DATE          BIRTH_DATE STATE  \
# 0  5ef3b4f17053ab141787697d 2020-06-24 20:17:54 2000-08-11 00:00:00    CA
# 1  5ff220d383fcfc12622b96bc 2021-01-03 19:53:55 2001-09-24 04:00:00    PA
# 2  6477950aa55bb77a0e27ee10 2023-05-31 18:42:18 1994-10-28 00:00:00    FL
# 3  658a306e99b40f103b63ccf8 2023-12-26 01:46:22                 NaT    NC
# 4  653cf5d6a225ea102b7ecdc2 2023-10-28 11:51:50 1972-03-19 00:00:00    PA
#
#   LANGUAGE  GENDER
# 0   es-419  female
# 1       en  female
# 2   es-419  female
# 3       en     NaN
# 4       en  female

# %%
# Check for uniqueness in ID
users['ID'].nunique()
# Out:
# 100000

# %%
# Save to users_cleaned.csv
users.to_csv('../data/processed/users_cleaned.csv', index=False)

# %% [markdown]
# ## Explore products

# %%
products
# Out:
#                CATEGORY_1                                CATEGORY_2  \
# 0       Health & Wellness                             Sexual Health
# 1                  Snacks                             Puffed Snacks
# 2       Health & Wellness                                 Hair Care
# 3       Health & Wellness                                 Oral Care
# 4       Health & Wellness                    Medicines & Treatments
# ...                   ...                                       ...
# 845547  Health & Wellness  Topical Muscle & Joint Relief Treatments
# 845548             Snacks                                   Cookies
# 845549             Snacks                                     Candy
# 845550             Snacks                              Nuts & Seeds
# 845551  Health & Wellness                                 First Aid
#
#                          CATEGORY_3 CATEGORY_4  \
# 0       Conductivity Gels & Lotions        NaN
# 1              Cheese Curls & Puffs        NaN
# 2             Hair Care Accessories        NaN
# 3                        Toothpaste        NaN
# 4                    Essential Oils        NaN
# ...                             ...        ...
# 845547               Braces & Wraps        NaN
# 845548                          NaN        NaN
# 845549             Confection Candy        NaN
# 845550                    Hazelnuts        NaN
# 845551               First Aid Kits        NaN
#
#                                              MANUFACTURER            BRAND  \
# 0                                                     NaN              NaN
# 1                                                     NaN              NaN
# 2                                PLACEHOLDER MANUFACTURER          ELECSOP
# 3                                       COLGATE-PALMOLIVE          COLGATE
# 4       MAPLE HOLISTICS AND HONEYDEW PRODUCTS INTERCHA...  MAPLE HOLISTICS
# ...                                                   ...              ...
# 845547                                                NaN              NaN
# 845548                              TREEHOUSE FOODS, INC.        LOFTHOUSE
# 845549                                HARIBO GMBH & CO KG           HARIBO
# 845550                                     DOUBLE-COLA CO            JUMBO
# 845551                                                 3M          NEXCARE
#
#              BARCODE
# 0       7.964944e+11
# 1       2.327801e+10
# 2       4.618178e+11
# 3       3.500047e+10
# 4       8.068109e+11
# ...              ...
# 845547  7.223016e+11
# 845548  4.182082e+10
# 845549  1.001672e+11
# 845550  7.539076e+10
# 845551  7.967933e+11
#
# [845552 rows x 7 columns]

# %%
# Checking the data
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845552 entries, 0 to 845551
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   CATEGORY_1    845441 non-null  object
#  1   CATEGORY_2    844128 non-null  object
#  2   CATEGORY_3    784986 non-null  object
#  3   CATEGORY_4    67459 non-null   object
#  4   MANUFACTURER  619078 non-null  object
#  5   BRAND         619080 non-null  object
#  6   BARCODE       841527 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 45.2+ MB

# %%
# Change data type of barcode to string
products['BARCODE'] = products['BARCODE'].astype(str)

# Checking the data
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845552 entries, 0 to 845551
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   CATEGORY_1    845441 non-null  object
#  1   CATEGORY_2    844128 non-null  object
#  2   CATEGORY_3    784986 non-null  object
#  3   CATEGORY_4    67459 non-null   object
#  4   MANUFACTURER  619078 non-null  object
#  5   BRAND         619080 non-null  object
#  6   BARCODE       845552 non-null  object
# dtypes: object(7)
# memory usage: 45.2+ MB

# %%
# Checking the shape of the data
products.shape
# Out:
# (845552, 7)

# %%
# Change all value as "nan" or "NaN" to null
products = products.replace(['nan', 'NaN'], np.nan)

# Remove duplicates
products = products.drop_duplicates()

# Checking the data
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 845337 entries, 0 to 845551
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   CATEGORY_1    845226 non-null  object
#  1   CATEGORY_2    843915 non-null  object
#  2   CATEGORY_3    784774 non-null  object
#  3   CATEGORY_4    67453 non-null   object
#  4   MANUFACTURER  618873 non-null  object
#  5   BRAND         618875 non-null  object
#  6   BARCODE       841369 non-null  object
# dtypes: object(7)
# memory usage: 51.6+ MB

# %%
products.shape
# Out:
# (845337, 7)

# %%
# Descriptive statistics
products.describe()
# Out:
#                CATEGORY_1 CATEGORY_2        CATEGORY_3 CATEGORY_4  \
# count              845226     843915            784774      67453
# unique                 27        121               344        127
# top     Health & Wellness      Candy  Confection Candy  Lip Balms
# freq               512686     120898             56951       9737
#
#                     MANUFACTURER      BRAND     BARCODE
# count                     618873     618875      841369
# unique                      4354       8122      841342
# top     PLACEHOLDER MANUFACTURER  REM BRAND  40111216.0
# freq                       86900      20813           2

# %%
# Checking for missing values
products.isnull().sum()
# Out:
# CATEGORY_1         111
# CATEGORY_2        1422
# CATEGORY_3       60563
# CATEGORY_4      777884
# MANUFACTURER    226464
# BRAND           226462
# BARCODE           3968
# dtype: int64

# %%
# Checking for uniqueness of each column
products.nunique()
# Out:
# CATEGORY_1          27
# CATEGORY_2         121
# CATEGORY_3         344
# CATEGORY_4         127
# MANUFACTURER      4354
# BRAND             8122
# BARCODE         841342
# dtype: int64

# %%
# Checking for duplicated barcodes
products['BARCODE'].duplicated().sum()
# Out:
# np.int64(3994)

# %%
# List the duplicated barcodes order by barcode
products[products['BARCODE'].duplicated(keep=False)].sort_values('BARCODE')
# Out:
#                CATEGORY_1              CATEGORY_2  \
# 428256  Health & Wellness               Skin Care
# 123194  Health & Wellness               Skin Care
# 304021  Health & Wellness               Hair Care
# 213340  Health & Wellness               Hair Care
# 783021             Snacks                 Cookies
# ...                   ...                     ...
# 845070  Health & Wellness  Medicines & Treatments
# 845187  Health & Wellness             Bath & Body
# 845215             Snacks                     NaN
# 845234  Health & Wellness               Oral Care
# 845363  Health & Wellness               Skin Care
#
#                          CATEGORY_3                CATEGORY_4  \
# 428256  Facial Lotion & Moisturizer                       NaN
# 123194       Lip Balms & Treatments  Medicated Lip Treatments
# 304021                   Hair Color                       NaN
# 213340                   Hair Color                       NaN
# 783021                          NaN                       NaN
# ...                             ...                       ...
# 845070                          NaN                       NaN
# 845187                          NaN                       NaN
# 845215                          NaN                       NaN
# 845234                          NaN                       NaN
# 845363             Facial Cleansers                       NaN
#
#                       MANUFACTURER                      BRAND        BARCODE
# 428256    R.M. PALMER COMPANY, LLC                     PALMER      1018158.0
# 123194  E.T. BROWNE DRUG CO., INC.  PALMER'S SKIN & HAIR CARE      1018158.0
# 304021                      HENKEL                      GÖT2B  17000329260.0
# 213340                      HENKEL                SCHWARZKOPF  17000329260.0
# 783021    PLACEHOLDER MANUFACTURER              PRIVATE LABEL     20031077.0
# ...                            ...                        ...            ...
# 845070           RECKITT BENCKISER                    CEPACOL            NaN
# 845187           RECKITT BENCKISER                    QUEEN V            NaN
# 845215                     PEPSICO                    IMAGINE            NaN
# 845234                      BOIRON                     BOIRON            NaN
# 845363            BEIERSDORF, INC.                 LA PRAIRIE            NaN
#
# [4022 rows x 7 columns]

# %%
# List the duplicated barcodes order by barcode where barcode is not null
products[products['BARCODE'].notnull() & products['BARCODE'].duplicated(keep=False)].sort_values('BARCODE')
# Out:
#                CATEGORY_1    CATEGORY_2                   CATEGORY_3  \
# 428256  Health & Wellness     Skin Care  Facial Lotion & Moisturizer
# 123194  Health & Wellness     Skin Care       Lip Balms & Treatments
# 304021  Health & Wellness     Hair Care                   Hair Color
# 213340  Health & Wellness     Hair Care                   Hair Color
# 783021             Snacks       Cookies                          NaN
# 132547             Snacks       Cookies                          NaN
# 56987              Snacks  Nuts & Seeds                      Almonds
# 776953             Snacks  Nuts & Seeds                 Covered Nuts
# 127335             Snacks  Nuts & Seeds                   Pistachios
# 260690             Snacks         Candy              Chocolate Candy
# 720019             Snacks      Crackers              Graham Crackers
# 206172             Snacks      Crackers              Graham Crackers
# 782036             Snacks         Chips                       Crisps
# 96438              Snacks      Crackers               Other Crackers
# 36017              Snacks         Candy           Candy Variety Pack
# 422809             Snacks         Candy              Chocolate Candy
# 144679             Snacks         Candy              Chocolate Candy
# 402382             Snacks         Candy             Confection Candy
# 528709             Snacks         Candy                          Gum
# 468720             Snacks         Candy                          Gum
# 766255             Snacks         Candy              Chocolate Candy
# 539918             Snacks         Candy                          Gum
# 717446             Snacks         Candy                          Gum
# 594684             Snacks         Candy                          Gum
# 379746             Snacks         Candy                          Gum
# 708466             Snacks         Candy                        Mints
# 193347             Snacks         Candy              Chocolate Candy
# 137250             Snacks  Nuts & Seeds                      Peanuts
# 454537             Snacks         Candy              Chocolate Candy
# 274698             Snacks         Candy              Chocolate Candy
# 139121             Snacks         Candy              Chocolate Candy
# 841230             Snacks         Candy              Chocolate Candy
# 668717  Health & Wellness     Skin Care                   Eye Creams
# 333771  Health & Wellness     Skin Care                   Eye Creams
# 287404             Snacks         Candy              Chocolate Candy
# 184572             Snacks         Candy              Chocolate Candy
# 709607  Health & Wellness     Hair Care                   Hair Color
# 28421   Health & Wellness     Hair Care                   Hair Color
# 596778  Health & Wellness     First Aid          Ointments & Liquids
# 768682  Health & Wellness     Skin Care    Skin Toners & Astringents
# 610681             Snacks  Nuts & Seeds                  Snack Seeds
# 645266             Snacks         Chips                       Crisps
# 114131             Snacks         Candy              Chocolate Candy
# 181902             Snacks         Candy             Confection Candy
# 162     Health & Wellness  Hair Removal          Shaving Gel & Cream
# 810359  Health & Wellness  Hair Removal          Shaving Gel & Cream
# 216314             Snacks         Candy              Chocolate Candy
# 585634             Snacks         Candy              Chocolate Candy
# 108325             Snacks         Candy                        Mints
# 300327             Snacks         Candy             Confection Candy
# 777589             Snacks         Candy                        Mints
# 37152              Snacks         Candy             Confection Candy
# 171015             Snacks  Nuts & Seeds                 Covered Nuts
# 681268             Snacks  Nuts & Seeds                      Almonds
#
#                          CATEGORY_4                      MANUFACTURER  \
# 428256                          NaN          R.M. PALMER COMPANY, LLC
# 123194     Medicated Lip Treatments        E.T. BROWNE DRUG CO., INC.
# 304021                          NaN                            HENKEL
# 213340                          NaN                            HENKEL
# 783021                          NaN          PLACEHOLDER MANUFACTURER
# 132547                          NaN                               NaN
# 56987                           NaN          PLACEHOLDER MANUFACTURER
# 776953                          NaN          PLACEHOLDER MANUFACTURER
# 127335                          NaN                      LIDL US, LLC
# 260690                          NaN                      LIDL US, LLC
# 720019                          NaN          PLACEHOLDER MANUFACTURER
# 206172                          NaN                      LIDL US, LLC
# 782036                          NaN          PLACEHOLDER MANUFACTURER
# 96438                           NaN                               NaN
# 36017                           NaN               THE HERSHEY COMPANY
# 422809                          NaN               THE HERSHEY COMPANY
# 144679                          NaN               THE HERSHEY COMPANY
# 402382                          NaN               THE HERSHEY COMPANY
# 528709                          NaN               THE HERSHEY COMPANY
# 468720                          NaN  GENERAL LICENSED IP MANUFACTURER
# 766255                          NaN               THE HERSHEY COMPANY
# 539918                          NaN               THE HERSHEY COMPANY
# 717446                          NaN  GENERAL LICENSED IP MANUFACTURER
# 594684                          NaN               THE HERSHEY COMPANY
# 379746                          NaN                               NaN
# 708466                          NaN                  LOTUS BRANDS INC
# 193347                          NaN                      MARS WRIGLEY
# 137250                          NaN                      MARS WRIGLEY
# 454537                          NaN                      MARS WRIGLEY
# 274698                          NaN                  PROCTER & GAMBLE
# 139121                          NaN          PLACEHOLDER MANUFACTURER
# 841230                          NaN                      MARS WRIGLEY
# 668717                          NaN              WALA HEILMITTEL GMBH
# 333771                          NaN                               NaN
# 287404                          NaN                            NESTLE
# 184572                          NaN                               NaN
# 709607                          NaN                            HENKEL
# 28421                           NaN                            HENKEL
# 596778                          NaN            THE JM SMUCKER COMPANY
# 768682                  Astringents            THE JM SMUCKER COMPANY
# 610681                          NaN                    SUNRIDGE FARMS
# 645266                          NaN                      TRADER JOE'S
# 114131                          NaN   GRUPO NACIONAL DE CHOCOLATES SA
# 181902                          NaN   GRUPO NACIONAL DE CHOCOLATES SA
# 162     Women's Shaving Gel & Cream          PLACEHOLDER MANUFACTURER
# 810359    Men's Shaving Gel & Cream          PLACEHOLDER MANUFACTURER
# 216314                          NaN                     FERRERO GROUP
# 585634                          NaN                          KINDER'S
# 108325                          NaN                PERFETTI VAN MELLE
# 300327                          NaN                PERFETTI VAN MELLE
# 777589                          NaN                PERFETTI VAN MELLE
# 37152                           NaN                PERFETTI VAN MELLE
# 171015                          NaN                      TRADER JOE'S
# 681268                          NaN                      TRADER JOE'S
#
#                             BRAND        BARCODE
# 428256                     PALMER      1018158.0
# 123194  PALMER'S SKIN & HAIR CARE      1018158.0
# 304021                      GÖT2B  17000329260.0
# 213340                SCHWARZKOPF  17000329260.0
# 783021              PRIVATE LABEL     20031077.0
# 132547                        NaN     20031077.0
# 56987             BRAND NOT KNOWN     20159078.0
# 776953            BRAND NOT KNOWN     20159078.0
# 127335                       LIDL     20522445.0
# 260690                       LIDL     20522445.0
# 720019              PRIVATE LABEL     20733056.0
# 206172                       LIDL     20733056.0
# 782036              PRIVATE LABEL     20733254.0
# 96438                         NaN     20733254.0
# 36017                   HERSHEY'S      3422007.0
# 422809                  HERSHEY'S      3422007.0
# 144679                    REESE'S      3431207.0
# 402382                    REESE'S      3431207.0
# 528709               ICE BREAKERS      3454503.0
# 468720                     DISNEY      3454503.0
# 766255                    REESE'S      3473009.0
# 539918                 BUBBLE YUM      3473009.0
# 717446                     DISNEY      3484708.0
# 594684               ICE BREAKERS      3484708.0
# 379746                        NaN    360054002.0
# 708466                   ECO-DENT    360054002.0
# 193347                      M&M'S      4003207.0
# 137250                      M&M'S      4003207.0
# 454537                       MARS     40111216.0
# 274698                     BOUNTY     40111216.0
# 139121            BRAND NOT KNOWN       404310.0
# 841230                      M&M'S       404310.0
# 668717                DR HAUSCHKA     42208488.0
# 333771                        NaN     42208488.0
# 287404                     NESTLE     50426171.0
# 184572                        NaN     50426171.0
# 709607                      GÖT2B  52336919068.0
# 28421                 SCHWARZKOPF  52336919068.0
# 596778                DICKINSON'S      5265169.0
# 768682                DICKINSON'S      5265169.0
# 610681             SUNRIDGE FARMS       701983.0
# 645266               TRADER JOE'S       701983.0
# 114131                    NUTRESA     75053055.0
# 181902                    NUTRESA     75053055.0
# 162                       PRORASO     80199137.0
# 810359                    PRORASO     80199137.0
# 216314                     KINDER     80310167.0
# 585634                   KINDER'S     80310167.0
# 108325                     MENTOS     87108538.0
# 300327                     MENTOS     87108538.0
# 777589                     MENTOS     87306286.0
# 37152                      MENTOS     87306286.0
# 171015               TRADER JOE'S       969307.0
# 681268               TRADER JOE'S       969307.0

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 845337 entries, 0 to 845551
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   CATEGORY_1    845226 non-null  object
#  1   CATEGORY_2    843915 non-null  object
#  2   CATEGORY_3    784774 non-null  object
#  3   CATEGORY_4    67453 non-null   object
#  4   MANUFACTURER  618873 non-null  object
#  5   BRAND         618875 non-null  object
#  6   BARCODE       841369 non-null  object
# dtypes: object(7)
# memory usage: 51.6+ MB

# %%
# Remove ".0" from end of barcode
products['BARCODE'] = products['BARCODE'].str.replace('.0', '')

products
# Out:
#                CATEGORY_1                                CATEGORY_2  \
# 0       Health & Wellness                             Sexual Health
# 1                  Snacks                             Puffed Snacks
# 2       Health & Wellness                                 Hair Care
# 3       Health & Wellness                                 Oral Care
# 4       Health & Wellness                    Medicines & Treatments
# ...                   ...                                       ...
# 845547  Health & Wellness  Topical Muscle & Joint Relief Treatments
# 845548             Snacks                                   Cookies
# 845549             Snacks                                     Candy
# 845550             Snacks                              Nuts & Seeds
# 845551  Health & Wellness                                 First Aid
#
#                          CATEGORY_3 CATEGORY_4  \
# 0       Conductivity Gels & Lotions        NaN
# 1              Cheese Curls & Puffs        NaN
# 2             Hair Care Accessories        NaN
# 3                        Toothpaste        NaN
# 4                    Essential Oils        NaN
# ...                             ...        ...
# 845547               Braces & Wraps        NaN
# 845548                          NaN        NaN
# 845549             Confection Candy        NaN
# 845550                    Hazelnuts        NaN
# 845551               First Aid Kits        NaN
#
#                                              MANUFACTURER            BRAND  \
# 0                                                     NaN              NaN
# 1                                                     NaN              NaN
# 2                                PLACEHOLDER MANUFACTURER          ELECSOP
# 3                                       COLGATE-PALMOLIVE          COLGATE
# 4       MAPLE HOLISTICS AND HONEYDEW PRODUCTS INTERCHA...  MAPLE HOLISTICS
# ...                                                   ...              ...
# 845547                                                NaN              NaN
# 845548                              TREEHOUSE FOODS, INC.        LOFTHOUSE
# 845549                                HARIBO GMBH & CO KG           HARIBO
# 845550                                     DOUBLE-COLA CO            JUMBO
# 845551                                                 3M          NEXCARE
#
#              BARCODE
# 0       796494407820
# 1        23278011028
# 2       461817824225
# 3        35000466815
# 4       806810850459
# ...              ...
# 845547  722301569399
# 845548   41820818468
# 845549  100167154940
# 845550   75390755960
# 845551  796793337781
#
# [845337 rows x 7 columns]

# %%
# Save the products data to products_cleaned.csv
products.to_csv('../data/processed/products_cleaned.csv', index=False)

# %% [markdown]
# ## Explore transactions

# %%
transactions
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1      0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3      000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
# ...                                     ...           ...
# 49995  b5cd61a9-8033-4913-a5c4-fb3f65e3a321    2024-08-21
# 49996  e1b2f634-c9ad-4152-b662-4b22efc25862    2024-08-11
# 49997  b07ef8dd-e444-40a2-819b-f74a3e5f1ae7    2024-07-11
# 49998  42475141-bef4-4df2-aa37-72577e2512bb    2024-06-18
# 49999  3a179c4e-46f2-4126-b3d2-3514afc23a3e    2024-08-07
#
#                        SCAN_DATE     STORE_NAME                   USER_ID  \
# 0      2024-08-21 14:19:06.539 Z        WALMART  63b73a7f3d310dceeabd4758
# 1      2024-07-20 09:50:24.206 Z           ALDI  62c08877baa38d1a1f6c211a
# 2      2024-08-19 15:38:56.813 Z        WALMART  60842f207ac8b7729e472020
# 3      2024-06-19 11:03:37.468 Z      FOOD LION  63fcd7cea4f8442c3386b589
# 4      2024-07-05 15:56:43.549 Z       RANDALLS  6193231ae9b3d75037b0f928
# ...                          ...            ...                       ...
# 49995  2024-08-31 14:13:08.634 Z         TARGET  6154bcf098f885648de2f299
# 49996  2024-08-11 18:15:56.736 Z    STOP & SHOP  60aa809f188b926b2244c974
# 49997  2024-07-11 08:03:25.816 Z        WALMART  60bd26e83dc3b13a15c5f4e7
# 49998  2024-06-18 19:57:32.211 Z  MARKET BASKET  6169912fac47744405af62b7
# 49999  2024-08-07 15:30:07.911 Z        WALMART  64e94d64ca929250373ef6e1
#
#             BARCODE FINAL_QUANTITY FINAL_SALE
# 0      1.530001e+10           1.00
# 1               NaN           zero       1.49
# 2      7.874223e+10           1.00
# 3      7.833997e+11           zero       3.49
# 4      4.790050e+10           1.00
# ...             ...            ...        ...
# 49995  8.523911e+10           2.00       1.18
# 49996  4.610040e+10           1.00       2.00
# 49997  6.466300e+11           1.00      20.96
# 49998  4.180050e+10           1.00       3.00
# 49999  3.076607e+11           1.00       5.48
#
# [50000 rows x 8 columns]

# %%
# Remove " Z" from end of date
transactions['SCAN_DATE'] = transactions['SCAN_DATE'].str.replace(' Z', '')

# Convert to datetime
transactions['SCAN_DATE'] = pd.to_datetime(transactions['SCAN_DATE'])

# Convert purchase_date to datetime
transactions['PURCHASE_DATE'] = pd.to_datetime(transactions['PURCHASE_DATE'], format='%Y-%m-%d')

# %%
# Replace "NaN" or "nan" with np.nan
transactions = transactions.replace('NaN', np.nan)
transactions = transactions.replace('nan', np.nan)

# Change data type of barcode to string
transactions['BARCODE'] = transactions['BARCODE'].astype(str)

# Remove ".0" from end of barcode
transactions['BARCODE'] = transactions['BARCODE'].str.replace('.0', '')

# Change "zero" in final_quantity to 0
transactions['FINAL_QUANTITY'] = transactions['FINAL_QUANTITY'].replace('zero', 0)

transactions
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1      0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3      000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
# ...                                     ...           ...
# 49995  b5cd61a9-8033-4913-a5c4-fb3f65e3a321    2024-08-21
# 49996  e1b2f634-c9ad-4152-b662-4b22efc25862    2024-08-11
# 49997  b07ef8dd-e444-40a2-819b-f74a3e5f1ae7    2024-07-11
# 49998  42475141-bef4-4df2-aa37-72577e2512bb    2024-06-18
# 49999  3a179c4e-46f2-4126-b3d2-3514afc23a3e    2024-08-07
#
#                     SCAN_DATE     STORE_NAME                   USER_ID  \
# 0     2024-08-21 14:19:06.539        WALMART  63b73a7f3d310dceeabd4758
# 1     2024-07-20 09:50:24.206           ALDI  62c08877baa38d1a1f6c211a
# 2     2024-08-19 15:38:56.813        WALMART  60842f207ac8b7729e472020
# 3     2024-06-19 11:03:37.468      FOOD LION  63fcd7cea4f8442c3386b589
# 4     2024-07-05 15:56:43.549       RANDALLS  6193231ae9b3d75037b0f928
# ...                       ...            ...                       ...
# 49995 2024-08-31 14:13:08.634         TARGET  6154bcf098f885648de2f299
# 49996 2024-08-11 18:15:56.736    STOP & SHOP  60aa809f188b926b2244c974
# 49997 2024-07-11 08:03:25.816        WALMART  60bd26e83dc3b13a15c5f4e7
# 49998 2024-06-18 19:57:32.211  MARKET BASKET  6169912fac47744405af62b7
# 49999 2024-08-07 15:30:07.911        WALMART  64e94d64ca929250373ef6e1
#
#             BARCODE FINAL_QUANTITY FINAL_SALE
# 0       15300014978           1.00
# 1               nan              0       1.49
# 2       78742229751           1.00
# 3      783399746536              0       3.49
# 4       47900501183           1.00
# ...             ...            ...        ...
# 49995   85239110669           2.00       1.18
# 49996   46100400555           1.00       2.00
# 49997  646630019670           1.00      20.96
# 49998   41800501519           1.00       3.00
# 49999  307660745853           1.00       5.48
#
# [50000 rows x 8 columns]

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RECEIPT_ID      50000 non-null  object
#  1   PURCHASE_DATE   50000 non-null  datetime64[ns]
#  2   SCAN_DATE       50000 non-null  datetime64[ns]
#  3   STORE_NAME      50000 non-null  object
#  4   USER_ID         50000 non-null  object
#  5   BARCODE         50000 non-null  object
#  6   FINAL_QUANTITY  50000 non-null  object
#  7   FINAL_SALE      50000 non-null  object
# dtypes: datetime64[ns](2), object(6)
# memory usage: 3.1+ MB

# %%
# Change ' ' to np.nan
transactions = transactions.replace(' ', np.nan)

# Change the data type of final_quantity and final_sale to float
transactions['FINAL_QUANTITY'] = transactions['FINAL_QUANTITY'].astype(float)
transactions['FINAL_SALE'] = transactions['FINAL_SALE'].astype(float)

transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RECEIPT_ID      50000 non-null  object
#  1   PURCHASE_DATE   50000 non-null  datetime64[ns]
#  2   SCAN_DATE       50000 non-null  datetime64[ns]
#  3   STORE_NAME      50000 non-null  object
#  4   USER_ID         50000 non-null  object
#  5   BARCODE         50000 non-null  object
#  6   FINAL_QUANTITY  50000 non-null  float64
#  7   FINAL_SALE      37500 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(4)
# memory usage: 3.1+ MB

# %%
# Check Top 5 rows
transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE               SCAN_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21 2024-08-21 14:19:06.539
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20 2024-07-20 09:50:24.206
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18 2024-08-19 15:38:56.813
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18 2024-06-19 11:03:37.468
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04 2024-07-05 15:56:43.549
#
#   STORE_NAME                   USER_ID       BARCODE  FINAL_QUANTITY  \
# 0    WALMART  63b73a7f3d310dceeabd4758   15300014978             1.0
# 1       ALDI  62c08877baa38d1a1f6c211a           nan             0.0
# 2    WALMART  60842f207ac8b7729e472020   78742229751             1.0
# 3  FOOD LION  63fcd7cea4f8442c3386b589  783399746536             0.0
# 4   RANDALLS  6193231ae9b3d75037b0f928   47900501183             1.0
#
#    FINAL_SALE
# 0         NaN
# 1        1.49
# 2         NaN
# 3        3.49
# 4         NaN

# %%
# Save the transactions data to transactions_cleaned.csv
transactions.to_csv('../data/processed/transactions_cleaned.csv', index=False)
